# %%
import matplotlib.pyplot as plt
import numpy as np

asdir = 'C:/Users/MAKINTERACT/makinteract/as/arr/as_62_30_arr.npy'
cedir = 'C:/Users/MAKINTERACT/makinteract/ce/arr/ce_72_26_arr.npy'
asarr = np.load(asdir)
cearr = np.load(cedir)
fig, axs = plt.subplots(2,1)
b = np.array([9000])
axs[0].plot(np.append(asarr,b))

axs[1].plot(np.append(cearr,b))

# %%
urdir = 'C:/Users/MAKINTERACT/makinteract/ur/arr/ur_67_20_arr.npy'
asdir = 'C:/Users/MAKINTERACT/makinteract/ur/arr/ur_65_3_arr.npy'
urarr = np.load(urdir)
asarr = np.load(asdir)
fig, axs = plt.subplots(2,1)
b = np.array([9000])
axs[0].plot(np.append(urarr,b))

axs[1].plot(np.append(asarr,b))

std = 0
for i in range(60):
    arrdir = 'C:/Users/MAKINTERACT/makinteract/ur/arr/ur_64_' + str(i+1)+ '_arr.npy'
    arr = np.load(arrdir)
    std += np.std(arr)
std /= 60
print(std)

std = 0
for i in range(60):
    arrdir = 'C:/Users/MAKINTERACT/makinteract/ur/arr/ur_65_' + str(i+1)+ '_arr.npy'
    arr = np.load(arrdir)
    std += np.std(arr)
std /= 60
print(std)

std = 0
for i in range(60):
    arrdir = 'C:/Users/MAKINTERACT/makinteract/ur/arr/ur_66_' + str(i+1)+ '_arr.npy'
    arr = np.load(arrdir)
    std += np.std(arr)
std /= 60
print(std)

std = 0
for i in range(60):
    arrdir = 'C:/Users/MAKINTERACT/makinteract/ur/arr/ur_67_' + str(i+1)+ '_arr.npy'
    arr = np.load(arrdir)
    std += np.std(arr)
std /= 60
print(std)
# Out:
# 44.520686863698614
# 26.986288257607455
# 31.92860246735484
# 24.914734947280074
